# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# commit id used to generate data ()
x = [50,100,150,200,250,300,350,400,450,500,550,600,650,700,750,800,850,900,950,1000,1050,1100,1150,1200,1250,1300,1350,1400,
     1450,1500,1550,1600,1650,1700,1750,1800,1850,1900,1950,2000,2050,2100,2150,2200,2250,2300,2350,2400,2450,2500,2550,2600,
     2650,2700,2750,2800,2850,2900,2950]
# numbers contained are not rounded 
splayTimes = [0.2717,0.2960,0.3131,0.3284,0.341661,0.35219,0.363739,0.372386,0.382005,0.389517,0.396586,0.404288,
              0.410215,0.416122,0.420925,0.425538,0.431016,0.437301,0.441661,0.446945,0.448363,0.459745,0.45584,0.462352,
              0.461145,0.468045,0.47158,0.475134,0.476596,0.483979,0.492736,0.492076,0.492101,0.498439,0.496107,0.499597,
              0.502357,0.50409,0.507834,0.50838,0.521454,0.518602,0.518602,0.51628,0.520491,0.523549,0.526586,0.529272,
              0.528839,0.531904,0.535376,0.536933,0.545798,0.545559,0.545486,0.543728,0.546268,0.552712,0.548905]
plt.plot(x, splayTimes, marker = '.')
avlTimes = [0.225305,0.236122,0.245702,0.255539,0.264075,0.270279,0.278142,0.283933,0.290326,0.294904,0.29984,0.304702,
            0.307821,0.31181,0.314276,0.317232,0.320931,0.324871,0.328023,0.331173,0.331899,0.34006,0.335645,0.340492,
            0.33859,0.34384,0.345915,0.348021,0.348956,0.354784,0.360853,0.359555,0.359169,0.364133,0.36153,0.363972,
            0.365151,0.366237,0.369089,0.368665,0.37929,0.376849,0.376111,0.373263,0.376613,0.378907,0.380977,0.382751,
            0.381917,0.383837,0.386768,0.387493,0.39484,0.393932,0.393129,0.392027,0.39294,0.398051,0.394349]
plt.plot(x, avlTimes, marker = '.')
plt.title("Avg find times of 50k norm dist numbers (tree size 1M - dist mean 500k)")
plt.xlabel("stddev 50 - 2950 (increments of 50)")
plt.ylabel("microseconds")
plt.legend(['Splay tree','AVL Tree'])
#plt.xticks(x, x)
plt.savefig('graphStddevCompare.pdf', bbox_inches='tight')
plt.show()
