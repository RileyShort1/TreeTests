# %%
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
# commit id used to generate data (d1e3c8c4c62328dc2c930a214d794f5ea396bf28)
x = [1,2,3,4,5]
splayTimes = [0.1820,0.1819,0.1821,0.1826,0.1818]
plt.plot(x, splayTimes, marker = 'o')
avlTimes = [0.1980,0.2023,0.2036,0.2051,0.2042]
plt.plot(x, avlTimes, marker = 'o')
plt.title("Avg find times of 50k norm dist numbers (stddev = 2, mean = 1/2 tree size)")
plt.xlabel("Tree Size (millions)")
plt.ylabel("microseconds")
plt.legend(['Splay tree','AVL Tree'])
plt.xticks(x, x)
plt.savefig('graphStddevCompare.pdf', bbox_inches='tight')
plt.show()
